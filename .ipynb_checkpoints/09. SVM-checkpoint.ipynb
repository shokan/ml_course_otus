# %% [markdown]
# # Задача
#
#
# http://archive.ics.uci.edu/ml/datasets/Abalone

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.linear_model import LogisticRegression
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Описание выборки
# **Abalone Data Set**
#
#     Name		Data Type	Meas.	Description
#     ----		---------	-----	-----------
#     Sex		nominal			M, F, and I (infant)
#     Length		continuous	mm	Longest shell measurement
#     Diameter		continuous	mm	perpendicular to length
#     Height		continuous	mm	with meat in shell
#     Whole weight		continuous	grams	whole abalone
#     Shucked weight		continuous	grams	weight of meat
#     Viscera weight		continuous	grams	gut weight (after bleeding)
#     Shell weight		continuous	grams	after being dried
#     Rings		integer			+1.5 gives the age in years

# %%
names = ["Sex", "Length", "Diameter", "Height", "Whole_weight",
         "Shucked_weight", "Viscera_weight", "Shell_weight", "Rings"]
df = pd.read_csv("datasets/abalone.data", names=names)

# %%
sns.barplot(data=df.Sex.value_counts().to_frame("count").reset_index(), x="count", y="index")
plt.show()

# %%
df.describe().T
# Out:
#                  count      mean       std     min     25%     50%     75%  \
# Length          4177.0  0.523992  0.120093  0.0750  0.4500  0.5450   0.615
# Diameter        4177.0  0.407881  0.099240  0.0550  0.3500  0.4250   0.480
# Height          4177.0  0.139516  0.041827  0.0000  0.1150  0.1400   0.165
# Whole_weight    4177.0  0.828742  0.490389  0.0020  0.4415  0.7995   1.153
# Shucked_weight  4177.0  0.359367  0.221963  0.0010  0.1860  0.3360   0.502
# Viscera_weight  4177.0  0.180594  0.109614  0.0005  0.0935  0.1710   0.253
# Shell_weight    4177.0  0.238831  0.139203  0.0015  0.1300  0.2340   0.329
# Rings           4177.0  9.933684  3.224169  1.0000  8.0000  9.0000  11.000
#
#                     max
# Length           0.8150
# Diameter         0.6500
# Height           1.1300
# Whole_weight     2.8255
# Shucked_weight   1.4880
# Viscera_weight   0.7600
# Shell_weight     1.0050
# Rings           29.0000

# %%
plt.figure(figsize=(10,7))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
sns.pairplot(data=df)
plt.show()

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X = df.drop("Sex", axis=1)
X_scaled = (X - X.mean()) / (X.std())
y = df.Sex

# %%
data=pd.concat([X_scaled, y], axis=1)

# %%
data = pd.melt(data,id_vars="Sex",
                    var_name="features",
                    value_name='value')

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x="features", y="value", hue="Sex", data=data)
plt.show()

# %% [markdown]
# # Моделирование

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((3341, 8), (836, 8), (3341,), (836,))

# %%
scalser = StandardScaler()
cls_lr = LogisticRegression()
cls_svm = svm.SVC()

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
cls_lr.fit(X_train_scaled, y_train)
cls_svm.fit(X_test_scaled, y_test)
# Out:
# /Users/shokan/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/shokan/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /Users/shokan/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
def model_metrics(pred, actual):
    print("acc: {}, \npre: {}, \nrecall: {}".format(accuracy_score(pred, actual), 
                                                        precision_score(pred, actual,
                                                                        pos_label='positive',
                                                                        average='micro'), 
                                                        recall_score(pred, actual,
                                                                     pos_label='positive',
                                                                     average='micro')))

# %%
model_metrics(cls_lr.predict(X_test), y_test)
# Out:
# acc: 0.37320574162679426,
# pre: 0.37320574162679426,
# recall: 0.37320574162679426
# /Users/shokan/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1259: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   % (pos_label, average), UserWarning)

# %%
model_metrics(cls_svm.predict(X_test), y_test)
# Out:
# acc: 0.3181818181818182,
# pre: 0.3181818181818182,
# recall: 0.3181818181818182
# /Users/shokan/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1259: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   % (pos_label, average), UserWarning)
